# %% [markdown]
# <a href="https://colab.research.google.com/github/NajwaQu/Praktikum_AI/blob/main/AI_BAB4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install keras-preprocessing
# Out:
# Requirement already satisfied: keras-preprocessing in /usr/local/lib/python3.12/dist-packages (1.1.2)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.12/dist-packages (from keras-preprocessing) (2.0.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from keras-preprocessing) (1.17.0)

# %%
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix
from nltk.tokenize import word_tokenize
from tensorflow.keras.utils import pad_sequences
from keras_preprocessing.text import Tokenizer
from keras.models import Model
from keras.layers import Input, Dense, LSTM, Dropout, concatenate, Embedding
from keras.utils import plot_model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/pemrograman /all_agree.csv')

# %%
df.head()
# Out:
#                                                title          label  \
# 0  Masuk Radar Pilwalkot Medan, Menantu Jokowi Be...  non-clickbait
# 1  Malaysia Sudutkan RI: Isu Kabut Asap hingga In...  non-clickbait
# 2  Viral! Driver Ojol di Bekasi Antar Pesanan Mak...      clickbait
# 3  Kemensos Salurkan Rp 7,3 M bagi Korban Kerusuh...  non-clickbait
# 4  MPR: Amandemen UUD 1945 Tak Akan Melebar ke Ma...  non-clickbait
#
#    label_score
# 0            0
# 1            0
# 2            1
# 3            0
# 4            0

# %%
df['label_score']. value_counts()
# Out:
# label_score
# 0    5297
# 1    3316
# Name: count, dtype: int64

# %%
def find_punc(x, punc):
  count = 0
  for char in x:
    if char == punc:
      count += 1
  return count

# %%
df['comma_count']   = df['title'].apply(lambda x: find_punc(x, ','))
df['fullstop_count'] = df['title'].apply(lambda x: find_punc(x, '.'))
df['exclaim_count']  = df['title'].apply(lambda x: find_punc(x, '!'))
df['question_count'] = df['title'].apply(lambda x: find_punc(x, '?'))
df['colon_count']    = df['title'].apply(lambda x: find_punc(x, ':'))
df['semicolon_count']= df['title'].apply(lambda x: find_punc(x, ';'))
df['apostrophe_count'] = df['title'].apply(lambda x: find_punc(x, "'"))

# %%
df.shape
# Out:
# (8613, 10)

# %%
def find_uppercase(x) :
  count = 0
  for char in x:
    if char.isupper() :
      count +=1
  return count

def find_lowercase(x) :
  count = 0
  for char in x:
    if char.islower() :
      count += 1
  return count

def find_number(x) :
  return len(re.findall('[0-9]', x))

# %%
df ['uppercase_count'] = df['title'].apply(find_uppercase)
df ['lowercase_count'] = df['title'].apply(find_lowercase)
df ['number_count'] = df['title'].apply(find_number)

# %%
df.shape
# Out:
# (8613, 13)

# %%
def clean(text):
  #LOWERING LETTERS
  text = text.lower()
  #REMOVING PUNCTUATIONS
  text = re.sub('[,.!?:;\']', '', text)
  #TOKENIZATION
  word_tokens = word_tokenize(text)
  #JOINING WORDS
  text = (' '.join(word_tokens))
  return text

# %%
import nltk
nltk.download('punkt_tab')
df['cleaned_title'] = df['title'].apply(clean)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
df[['title', 'cleaned_title']]
# Out:
#                                                   title  \
# 0     Masuk Radar Pilwalkot Medan, Menantu Jokowi Be...
# 1     Malaysia Sudutkan RI: Isu Kabut Asap hingga In...
# 2     Viral! Driver Ojol di Bekasi Antar Pesanan Mak...
# 3     Kemensos Salurkan Rp 7,3 M bagi Korban Kerusuh...
# 4     MPR: Amandemen UUD 1945 Tak Akan Melebar ke Ma...
# ...                                                 ...
# 8608  Twice Rilis Teaser MV 'Feel Special' Jelang Co...
# 8609   Asap Karhutla Riau Mulai Merambah Ke Nias, BM...
# 8610  Tolak RUU Pertanahan, Ribuan Petani Siap Gelar...
# 8611  Ada Niat Tambah Momongan Tanpa Ikut Program Ha...
# 8612   TXT Akan Segera Comeback, Soobin Akui Gatal I...
#
#                                           cleaned_title
# 0     masuk radar pilwalkot medan menantu jokowi ber...
# 1     malaysia sudutkan ri isu kabut asap hingga inv...
# 2     viral driver ojol di bekasi antar pesanan maka...
# 3     kemensos salurkan rp 73 m bagi korban kerusuha...
# 4     mpr amandemen uud 1945 tak akan melebar ke man...
# ...                                                 ...
# 8608  twice rilis teaser mv feel special jelang come...
# 8609  asap karhutla riau mulai merambah ke nias bmkg...
# 8610  tolak ruu pertanahan ribuan petani siap gelar ...
# 8611  ada niat tambah momongan tanpa ikut program ha...
# 8612  txt akan segera comeback soobin akui gatal ing...
#
# [8613 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['title', 'label', 'label_score', 'comma_count', 'fullstop_count',
#        'exclaim_count', 'question_count', 'colon_count', 'semicolon_count',
#        'apostrophe_count', 'uppercase_count', 'lowercase_count',
#        'number_count', 'cleaned_title'],
#       dtype='object')

# %%
X = df.iloc[:, 3:]
y = df.iloc[:, 2]

# %%
X_train, X_test, y_train, y_test = train_test_split (X, y,
                                                     test_size=0.2,
                                                     random_state=77)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (6890, 11)
# (1723, 11)

# %%
X_train_title = X_train['cleaned_title']
X_test_title = X_test['cleaned_title']

X_train_punch = X_train.drop('cleaned_title', axis=1)
X_test_punch = X_test.drop('cleaned_title', axis=1)
#

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train_title)

X_train_title = tokenizer.texts_to_sequences(X_train_title)
X_test_title = tokenizer.texts_to_sequences(X_test_title)

# %%
tokenizer.word_index
# Out:
# {'di': 1,
#  'ini': 2,
#  'dan': 3,
#  'yang': 4,
#  'ke': 5,
#  'jadi': 6,
#  'kpk': 7,
#  '2019': 8,
#  'indonesia': 9,
#  'tak': 10,
#  'untuk': 11,
#  'dengan': 12,
#  'habibie': 13,
#  'dari': 14,
#  'dpr': 15,
#  'polisi': 16,
#  'jokowi': 17,
#  'saat': 18,
#  'soal': 19,
#  'akan': 20,
#  'uu': 21,
#  'anak': 22,
#  'baru': 23,
#  'minta': 24,
#  'ada': 25,
#  'mahasiswa': 26,
#  'bisa': 27,
#  'hingga': 28,
#  'demo': 29,
#  'bikin': 30,
#  '3': 31,
#  'asap': 32,
#  'vs': 33,
#  'kota': 34,
#  'revisi': 35,
#  '5': 36,
#  'gara': 37,
#  'hari': 38,
#  'papua': 39,
#  'bj': 40,
#  'orang': 41,
#  '4': 42,
#  'tahun': 43,
#  '2': 44,
#  'usai': 45,
#  'liga': 46,
#  'sebut': 47,
#  'warga': 48,
#  'bakal': 49,
#  'rumah': 50,
#  'sinopsis': 51,
#  '1': 52,
#  'begini': 53,
#  'dalam': 54,
#  'dunia': 55,
#  'gelar': 56,
#  'kabut': 57,
#  'ibu': 58,
#  'jakarta': 59,
#  'siap': 60,
#  'rp': 61,
#  'foto': 62,
#  'karena': 63,
#  'jalan': 64,
#  'mobil': 65,
#  'sudah': 66,
#  'apa': 67,
#  'lebih': 68,
#  'dki': 69,
#  'pemerintah': 70,
#  'episode': 71,
#  'korban': 72,
#  '2020': 73,
#  'masih': 74,
#  'kasus': 75,
#  'air': 76,
#  'ingin': 77,
#  'karhutla': 78,
#  'tidak': 79,
#  'kembali': 80,
#  'aksi': 81,
#  'alasan': 82,
#  'pada': 83,
#  'cinta': 84,
#  'viral': 85,
#  'beri': 86,
#  'naik': 87,
#  'anggota': 88,
#  'presiden': 89,
#  'pakai': 90,
#  'juta': 91,
#  'tewas': 92,
#  'lagi': 93,
#  'ruu': 94,
#  'cara': 95,
#  'dprd': 96,
#  'ungkap': 97,
#  'video': 98,
#  'fakta': 99,
#  'harga': 100,
#  'tayang': 101,
#  '6': 102,
#  'timnas': 103,
#  '10': 104,
#  'sinetron': 105,
#  'meninggal': 106,
#  'ikut': 107,
#  'belum': 108,
#  'menteri': 109,
#  'hasil': 110,
#  'dua': 111,
#  'kata': 112,
#  'pertama': 113,
#  'china': 114,
#  'tersangka': 115,
#  'tolak': 116,
#  'anies': 117,
#  '16': 118,
#  'bareng': 119,
#  '7': 120,
#  'film': 121,
#  'zodiak': 122,
#  'drama': 123,
#  'harus': 124,
#  'as': 125,
#  'dapat': 126,
#  'kebakaran': 127,
#  'jelang': 128,
#  'minyak': 129,
#  'suami': 130,
#  'ketua': 131,
#  'pria': 132,
#  'diri': 133,
#  'setelah': 134,
#  'saudi': 135,
#  'kesehatan': 136,
#  'masuk': 137,
#  'listrik': 138,
#  'genap': 139,
#  'punya': 140,
#  'pernah': 141,
#  'tol': 142,
#  'depan': 143,
#  'ganjil': 144,
#  'pemain': 145,
#  'pelajar': 146,
#  'turun': 147,
#  'bandara': 148,
#  'paling': 149,
#  'open': 150,
#  'bts': 151,
#  'pimpinan': 152,
#  'riau': 153,
#  'tni': 154,
#  'sempat': 155,
#  'diduga': 156,
#  'malaysia': 157,
#  'istri': 158,
#  'ternyata': 159,
#  'banyak': 160,
#  'united': 161,
#  'fans': 162,
#  'lakukan': 163,
#  'hutan': 164,
#  'netizen': 165,
#  'disebut': 166,
#  'mulai': 167,
#  '8': 168,
#  'terbakar': 169,
#  'massa': 170,
#  'ri': 171,
#  'mantan': 172,
#  '11': 173,
#  'tanpa': 174,
#  'jadwal': 175,
#  'u': 176,
#  'industri': 177,
#  'buka': 178,
#  'bulan': 179,
#  'inggris': 180,
#  "''": 181,
#  'siapa': 182,
#  'negara': 183,
#  'september': 184,
#  'kali': 185,
#  'gubernur': 186,
#  'lewat': 187,
#  'mau': 188,
#  'satu': 189,
#  'lee': 190,
#  'bersama': 191,
#  'malah': 192,
#  'tetap': 193,
#  'the': 194,
#  'resmi': 195,
#  'akui': 196,
#  'masyarakat': 197,
#  'bukan': 198,
#  'miliar': 199,
#  'bagi': 200,
#  'bebby': 201,
#  'fey': 202,
#  'cerita': 203,
#  '9': 204,
#  'dukung': 205,
#  'pamer': 206,
#  'segera': 207,
#  'emas': 208,
#  'sekolah': 209,
#  'terima': 210,
#  'thailand': 211,
#  'jangan': 212,
#  'buat': 213,
#  'tampil': 214,
#  'cantik': 215,
#  'sebagai': 216,
#  'besar': 217,
#  '0': 218,
#  'akhir': 219,
#  'bank': 220,
#  'tiga': 221,
#  'barat': 222,
#  'bekasi': 223,
#  'april': 224,
#  'nama': 225,
#  'cukai': 226,
#  'atas': 227,
#  'hanya': 228,
#  'seperti': 229,
#  'ekonomi': 230,
#  'pekan': 231,
#  'piala': 232,
#  'lahan': 233,
#  'kecelakaan': 234,
#  'capim': 235,
#  'akibat': 236,
#  'sebelum': 237,
#  'bangun': 238,
#  'serangan': 239,
#  'keluarga': 240,
#  'bali': 241,
#  'sukses': 242,
#  'raih': 243,
#  'paris': 244,
#  'babak': 245,
#  'gempa': 246,
#  'hal': 247,
#  'calon': 248,
#  'dorong': 249,
#  'makin': 250,
#  'sama': 251,
#  'investasi': 252,
#  '15': 253,
#  'istana': 254,
#  'ahmad': 255,
#  'sang': 256,
#  'uang': 257,
#  'persen': 258,
#  'kerja': 259,
#  'artis': 260,
#  'perlu': 261,
#  'm': 262,
#  'tim': 263,
#  'program': 264,
#  'wali': 265,
#  'tips': 266,
#  'luna': 267,
#  'bunga': 268,
#  'barbie': 269,
#  'beli': 270,
#  'triliun': 271,
#  'dewan': 272,
#  'tapi': 273,
#  'alami': 274,
#  'terus': 275,
#  'muda': 276,
#  'kepala': 277,
#  'mati': 278,
#  'imam': 279,
#  'langsung': 280,
#  'polri': 281,
#  'agar': 282,
#  'iran': 283,
#  'pasar': 284,
#  'pesan': 285,
#  'ihsg': 286,
#  'rokok': 287,
#  'lagu': 288,
#  'pembangunan': 289,
#  'motor': 290,
#  'ratusan': 291,
#  'ajak': 292,
#  'festival': 293,
#  'veronica': 294,
#  'ditangkap': 295,
#  'hadapi': 296,
#  'ribu': 297,
#  'sering': 298,
#  'kirim': 299,
#  '100': 300,
#  'eks': 301,
#  'sampai': 302,
#  'akhirnya': 303,
#  'siapkan': 304,
#  'nahrawi': 305,
#  'bpjs': 306,
#  'hukum': 307,
#  'rkuhp': 308,
#  'narkoba': 309,
#  'kuhp': 310,
#  'bertemu': 311,
#  '17': 312,
#  'super': 313,
#  'mei': 314,
#  'pelatih': 315,
#  'diminta': 316,
#  'tuai': 317,
#  'malam': 318,
#  'bahas': 319,
#  'pb': 320,
#  'djarum': 321,
#  'kisah': 322,
#  'undang': 323,
#  'wanita': 324,
#  'per': 325,
#  'dinilai': 326,
#  'koman': 327,
#  'sri': 328,
#  'setuju': 329,
#  'perusahaan': 330,
#  'jika': 331,
#  'ribuan': 332,
#  'kivlan': 333,
#  'bandung': 334,
#  'mata': 335,
#  'live': 336,
#  'siswa': 337,
#  'kumalasari': 338,
#  'luar': 339,
#  'tangkap': 340,
#  'halilintar': 341,
#  'kamu': 342,
#  'tinggi': 343,
#  'atau': 344,
#  'tahu': 345,
#  'man': 346,
#  'lain': 347,
#  'alasannya': 348,
#  'jabar': 349,
#  'hamil': 350,
#  'kualifikasi': 351,
#  'sakit': 352,
#  'penyebab': 353,
#  'hati': 354,
#  'tentang': 355,
#  'kini': 356,
#  'bawa': 357,
#  'gagal': 358,
#  'lokasi': 359,
#  'medan': 360,
#  'rapat': 361,
#  'wisata': 362,
#  'balik': 363,
#  'pesawat': 364,
#  'atta': 365,
#  'polda': 366,
#  'korea': 367,
#  'putra': 368,
#  'madrid': 369,
#  'nasional': 370,
#  'jam': 371,
#  'kondisi': 372,
#  'terbaik': 373,
#  'gunung': 374,
#  'puluhan': 375,
#  'solo': 376,
#  'blackpink': 377,
#  'syahrini': 378,
#  'saja': 379,
#  'kedua': 380,
#  'champions': 381,
#  'liverpool': 382,
#  'lawan': 383,
#  'rusuh': 384,
#  'sidang': 385,
#  'atasi': 386,
#  'rupiah': 387,
#  'surabaya': 388,
#  'demi': 389,
#  'audisi': 390,
#  'seorang': 391,
#  'oktober': 392,
#  'bogor': 393,
#  'bantah': 394,
#  'perempuan': 395,
#  'trump': 396,
#  'korupsi': 397,
#  'zen': 398,
#  'nikita': 399,
#  'makan': 400,
#  'sampah': 401,
#  'penjelasan': 402,
#  'rilis': 403,
#  'dana': 404,
#  'komisi': 405,
#  'pbb': 406,
#  'komentar': 407,
#  'juara': 408,
#  'pemprov': 409,
#  'capai': 410,
#  'online': 411,
#  'ulang': 412,
#  'bayi': 413,
#  '20': 414,
#  'sorotan': 415,
#  'bantu': 416,
#  'mengaku': 417,
#  'gerindra': 418,
#  'anggaran': 419,
#  'terakhir': 420,
#  'gandeng': 421,
#  'negeri': 422,
#  'pilih': 423,
#  'exo': 424,
#  'persib': 425,
#  'intip': 426,
#  'pdip': 427,
#  'tempat': 428,
#  'daftar': 429,
#  'reaksi': 430,
#  'penerbangan': 431,
#  'umum': 432,
#  'terkait': 433,
#  'pengesahan': 434,
#  'kamis': 435,
#  'hujan': 436,
#  'udara': 437,
#  'mirzani': 438,
#  'gunakan': 439,
#  'bi': 440,
#  'suku': 441,
#  'itu': 442,
#  'mulyani': 443,
#  'pegawai': 444,
#  'eropa': 445,
#  'partai': 446,
#  'makassar': 447,
#  'masalah': 448,
#  'sendiri': 449,
#  'pastikan': 450,
#  'para': 451,
#  'hotman': 452,
#  'janji': 453,
#  'australia': 454,
#  'seksi': 455,
#  'tidur': 456,
#  'luncurkan': 457,
#  'bupati': 458,
#  'terjadi': 459,
#  'pengusaha': 460,
#  'mewah': 461,
#  'pernikahan': 462,
#  'kim': 463,
#  'ngaku': 464,
#  'wakil': 465,
#  'besok': 466,
#  'perluasan': 467,
#  'terungkap': 468,
#  'nilai': 469,
#  'trotoar': 470,
#  'sosok': 471,
#  'liburan': 472,
#  'lalu': 473,
#  'menpora': 474,
#  'terbaru': 475,
#  'bukti': 476,
#  'perang': 477,
#  'persija': 478,
#  'susi': 479,
#  'raffi': 480,
#  'main': 481,
#  'proyek': 482,
#  'putri': 483,
#  'politik': 484,
#  'batu': 485,
#  'tokoh': 486,
#  'saya': 487,
#  'pasal': 488,
#  'hye': 489,
#  'hilang': 490,
#  'tetapkan': 491,
#  '30': 492,
#  'pln': 493,
#  'data': 494,
#  'heboh': 495,
#  'kembangkan': 496,
#  'izin': 497,
#  'fashion': 498,
#  'kilang': 499,
#  'suka': 500,
#  'tengah': 501,
#  'tanah': 502,
#  'bongkar': 503,
#  'oleh': 504,
#  'pelaku': 505,
#  'diprediksi': 506,
#  'top': 507,
#  'bayar': 508,
#  'ekspor': 509,
#  'prediksi': 510,
#  'pilkada': 511,
#  'ketiga': 512,
#  '19': 513,
#  'cegah': 514,
#  'gaya': 515,
#  'hidup': 516,
#  'digital': 517,
#  'juga': 518,
#  'pabrik': 519,
#  'pasca': 520,
#  'kemenhub': 521,
#  'pajak': 522,
#  'perdana': 523,
#  'hotel': 524,
#  'salah': 525,
#  'kantor': 526,
#  'kena': 527,
#  'golkar': 528,
#  'kerusuhan': 529,
#  'se': 530,
#  'mana': 531,
#  'lengkap': 532,
#  'anaknya': 533,
#  'arsenal': 534,
#  'amerika': 535,
#  'penumpang': 536,
#  'streaming': 537,
#  'petugas': 538,
#  'kendaraan': 539,
#  'manfaat': 540,
#  'rambut': 541,
#  'mu': 542,
#  'rabu': 543,
#  'umumkan': 544,
#  'coba': 545,
#  'wajah': 546,
#  'rekor': 547,
#  'panas': 548,
#  'sumut': 549,
#  'impor': 550,
#  'gol': 551,
#  'bentuk': 552,
#  'kulit': 553,
#  'menarik': 554,
#  'bantuan': 555,
#  'api': 556,
#  'idol': 557,
#  'menang': 558,
#  'mandiri': 559,
#  'utang': 560,
#  'peserta': 561,
#  'tegaskan': 562,
#  'dampak': 563,
#  'ayam': 564,
#  'ancam': 565,
#  'tingkatkan': 566,
#  'desak': 567,
#  'fahri': 568,
#  'menguat': 569,
#  'pro': 570,
#  'ainun': 571,
#  'pengawas': 572,
#  'jambi': 573,
#  'pagi': 574,
#  'syuting': 575,
#  'aplikasi': 576,
#  'demokrat': 577,
#  'wagub': 578,
#  'bocah': 579,
#  'diamankan': 580,
#  'temukan': 581,
#  'asal': 582,
#  'pasangan': 583,
#  'pejabat': 584,
#  'guru': 585,
#  'berikut': 586,
#  'jayapura': 587,
#  'daerah': 588,
#  'kaki': 589,
#  'google': 590,
#  'twice': 591,
#  'x': 592,
#  'status': 593,
#  'truk': 594,
#  'senin': 595,
#  'panggil': 596,
#  'kritik': 597,
#  'merasa': 598,
#  'red': 599,
#  'utara': 600,
#  'tangsel': 601,
#  'dewi': 602,
#  'city': 603,
#  'jenazah': 604,
#  'langit': 605,
#  'bagaimana': 606,
#  'desa': 607,
#  'luka': 608,
#  'tv': 609,
#  'bunuh': 610,
#  'iii': 611,
#  'arab': 612,
#  'bahan': 613,
#  'grup': 614,
#  'comeback': 615,
#  'ronaldo': 616,
#  'bea': 617,
#  'damai': 618,
#  'bmkg': 619,
#  'pemkot': 620,
#  'kpai': 621,
#  'berat': 622,
#  'tangan': 623,
#  'laga': 624,
#  'drone': 625,
#  'baju': 626,
#  'ala': 627,
#  'penghargaan': 628,
#  'ham': 629,
#  'jatim': 630,
#  'usia': 631,
#  'baik': 632,
#  'bicara': 633,
#  'bumn': 634,
#  'ii': 635,
#  'fc': 636,
#  'pak': 637,
#  'petani': 638,
#  'kabar': 639,
#  'serang': 640,
#  'ikuti': 641,
#  'iphone': 642,
#  'mirip': 643,
#  '23': 644,
#  'sun': 645,
#  'ditutup': 646,
#  'turunkan': 647,
#  'terhadap': 648,
#  'suara': 649,
#  'wamena': 650,
#  'dekat': 651,
#  'kalimantan': 652,
#  'ikan': 653,
#  'sistem': 654,
#  'jk': 655,
#  'lihat': 656,
#  'panjang': 657,
#  'dinas': 658,
#  'jateng': 659,
#  'jalani': 660,
#  'produksi': 661,
#  '12': 662,
#  'wiranto': 663,
#  'bus': 664,
#  'medsos': 665,
#  'ilegal': 666,
#  'jalur': 667,
#  'hong': 668,
#  'kawasan': 669,
#  'pemkab': 670,
#  '18': 671,
#  'respons': 672,
#  'mundur': 673,
#  'masa': 674,
#  'cari': 675,
#  '50': 676,
#  'peluang': 677,
#  'ambon': 678,
#  'sejumlah': 679,
#  'minum': 680,
#  'sepeda': 681,
#  'baswedan': 682,
#  'ditemukan': 683,
#  'suci': 684,
#  'mereka': 685,
#  'ajukan': 686,
#  'dugaan': 687,
#  'still': 688,
#  'resep': 689,
#  'kami': 690,
#  'surat': 691,
#  'kalah': 692,
#  'cs': 693,
#  'perhatian': 694,
#  'show': 695,
#  'investor': 696,
#  'penjualan': 697,
#  'meski': 698,
#  'temui': 699,
#  'asia': 700,
#  'kopi': 701,
#  'motogp': 702,
#  'protes': 703,
#  'week': 704,
#  'smp': 705,
#  'poin': 706,
#  'pertamina': 707,
#  'dianggap': 708,
#  'rasa': 709,
#  'sby': 710,
#  'meluncur': 711,
#  'maya': 712,
#  'dipuji': 713,
#  'menangis': 714,
#  'ridwan': 715,
#  'kamil': 716,
#  'e': 717,
#  'ricuh': 718,
#  'emak': 719,
#  'barcelona': 720,
#  'jepang': 721,
#  'garuda': 722,
#  'pekat': 723,
#  'asing': 724,
#  'ngakak': 725,
#  'member': 726,
#  'terluka': 727,
#  'wilayah': 728,
#  'bola': 729,
#  'nct': 730,
#  'raditya': 731,
#  'i': 732,
#  'jefri': 733,
#  'nichol': 734,
#  'mpr': 735,
#  'gabung': 736,
#  'nggak': 737,
#  'muncul': 738,
#  'buta': 739,
#  'tanggapan': 740,
#  'sejak': 741,
#  'wajib': 742,
#  'shin': 743,
#  'aturan': 744,
#  'cina': 745,
#  'pelantikan': 746,
#  'honda': 747,
#  'mulan': 748,
#  'bpk': 749,
#  'ambil': 750,
#  'gedung': 751,
#  'kalau': 752,
#  'islam': 753,
#  'semakin': 754,
#  'cukup': 755,
#  'bak': 756,
#  '22': 757,
#  'level': 758,
#  'buruk': 759,
#  'sindir': 760,
#  'ramai': 761,
#  'k': 762,
#  'sumsel': 763,
#  'sepanjang': 764,
#  'kong': 765,
#  'singapura': 766,
#  'psg': 767,
#  'si': 768,
#  'semua': 769,
#  'debut': 770,
#  'nikah': 771,
#  'netter': 772,
#  'kocak': 773,
#  'hoaks': 774,
#  'antam': 775,
#  'iuran': 776,
#  'butuh': 777,
#  'kuat': 778,
#  'haji': 779,
#  'simak': 780,
#  'cepat': 781,
#  'atlet': 782,
#  'milan': 783,
#  'halal': 784,
#  'spanyol': 785,
#  'saham': 786,
#  'disahkan': 787,
#  'and': 788,
#  'dika': 789,
#  'operasi': 790,
#  'cek': 791,
#  'young': 792,
#  'ting': 793,
#  'hampir': 794,
#  'pemuda': 795,
#  'daniel': 796,
#  'kelas': 797,
#  'nagita': 798,
#  'ditunda': 799,
#  'era': 800,
#  'tembak': 801,
#  'senjata': 802,
#  'bekas': 803,
#  'selama': 804,
#  'brimob': 805,
#  'beroperasi': 806,
#  'keren': 807,
#  'ingatkan': 808,
#  'serahkan': 809,
#  'selatan': 810,
#  'bisnis': 811,
#  'depok': 812,
#  'ambulans': 813,
#  'publik': 814,
#  'cuma': 815,
#  'selasa': 816,
#  'pesantren': 817,
#  'beredar': 818,
#  'bapak': 819,
#  'jawa': 820,
#  'jerman': 821,
#  'penuh': 822,
#  'pacar': 823,
#  'berhenti': 824,
#  'bagikan': 825,
#  'adik': 826,
#  'musim': 827,
#  'kualitas': 828,
#  'gigi': 829,
#  '40': 830,
#  'produk': 831,
#  'konser': 832,
#  'tsunami': 833,
#  'kita': 834,
#  'amankan': 835,
#  'pulang': 836,
#  'kepada': 837,
#  'bebas': 838,
#  'inilah': 839,
#  'pakar': 840,
#  'pop': 841,
#  'semarang': 842,
#  'cetak': 843,
#  'postingan': 844,
#  'ditahan': 845,
#  'ganteng': 846,
#  'sangat': 847,
#  'masjid': 848,
#  'real': 849,
#  'waktu': 850,
#  'bela': 851,
#  'gratis': 852,
#  'makanan': 853,
#  'dibuka': 854,
#  'empat': 855,
#  'dukungan': 856,
#  'kementan': 857,
#  'berbahaya': 858,
#  'sriwijaya': 859,
#  'penampilan': 860,
#  'dikabarkan': 861,
#  'toyota': 862,
#  'terpilih': 863,
#  'asn': 864,
#  'skor': 865,
#  'gibran': 866,
#  'tua': 867,
#  'filipina': 868,
#  'evaluasi': 869,
#  'selain': 870,
#  'targetkan': 871,
#  'bulu': 872,
#  'velvet': 873,
#  'cewek': 874,
#  'titik': 875,
#  'ganja': 876,
#  'fraksi': 877,
#  'rayakan': 878,
#  'mafia': 879,
#  'tawarkan': 880,
#  'pengacara': 881,
#  'potret': 882,
#  'sehat': 883,
#  'marquez': 884,
#  'yuk': 885,
#  'aman': 886,
#  'jong': 887,
#  'selalu': 888,
#  '25': 889,
#  'ditetapkan': 890,
#  'unggah': 891,
#  'telah': 892,
#  'siang': 893,
#  'pemindahan': 894,
#  'menhub': 895,
#  'pengendara': 896,
#  'kenaikan': 897,
#  'jumlah': 898,
#  'fokus': 899,
#  'posisi': 900,
#  'pertemuan': 901,
#  'penyakit': 902,
#  'dokter': 903,
#  'gading': 904,
#  'lima': 905,
#  'rusia': 906,
#  'harap': 907,
#  'teroris': 908,
#  'jawaban': 909,
#  'apresiasi': 910,
#  'aramco': 911,
#  'diserang': 912,
#  'tanda': 913,
#  'tangerang': 914,
#  'aktivis': 915,
#  'ramalan': 916,
#  'berpotensi': 917,
#  'maut': 918,
#  'media': 919,
#  'pariwisata': 920,
#  'banjir': 921,
#  'agung': 922,
#  'kalahkan': 923,
#  'cerai': 924,
#  'isu': 925,
#  'teman': 926,
#  'belajar': 927,
#  'wafat': 928,
#  'kekerasan': 929,
#  'dirut': 930,
#  'isyaratkan': 931,
#  'beda': 932,
#  'periksa': 933,
#  'bos': 934,
#  'terganggu': 935,
#  'penting': 936,
#  'panglima': 937,
#  'angkat': 938,
#  'siaran': 939,
#  'persipura': 940,
#  'jaga': 941,
#  'min': 942,
#  'paripurna': 943,
#  'juventus': 944,
#  'rencana': 945,
#  'properti': 946,
#  'yakin': 947,
#  'pesta': 948,
#  'puji': 949,
#  'de': 950,
#  'target': 951,
#  'rahasia': 952,
#  'digelar': 953,
#  'laki': 954,
#  'lapor': 955,
#  'ganti': 956,
#  'benar': 957,
#  'tanggapi': 958,
#  'singgung': 959,
#  'reino': 960,
#  'alat': 961,
#  'proses': 962,
#  'group': 963,
#  'mampu': 964,
#  'terbitkan': 965,
#  'kapal': 966,
#  'tunggu': 967,
#  'tepat': 968,
#  'model': 969,
#  'uji': 970,
#  'manchester': 971,
#  'kemarau': 972,
#  'pupr': 973,
#  'jaya': 974,
#  'final': 975,
#  'aceh': 976,
#  'usaha': 977,
#  'unik': 978,
#  'bangsa': 979,
#  'kenapa': 980,
#  'internasional': 981,
#  'tuntut': 982,
#  'sulit': 983,
#  'posting': 984,
#  'hamzah': 985,
#  'gerakan': 986,
#  'beberkan': 987,
#  'jatuh': 988,
#  'ramah': 989,
#  'lingkungan': 990,
#  'milik': 991,
#  'tembus': 992,
#  'bumi': 993,
#  'daihatsu': 994,
#  'keuangan': 995,
#  'selamat': 996,
#  'tubuh': 997,
#  'asli': 998,
#  'bawah': 999,
#  'lintas': 1000,
#  ...}

# %%
vocab_size = len(tokenizer.word_index)
vocab_size
# Out:
# 12342

# %%
lengths = []
for sentence in X_train_title:
  lengths.append(len(sentence))

print('Longest sentence\t:', max(lengths))
print('Shortest sentence\t:', min(lengths))
print('Average length\t\t:', np.mean(lengths))
# Out:
# Longest sentence	: 19
# Shortest sentence	: 2
# Average length		: 9.738606676342526

# %%
X_train_title = pad_sequences(X_train_title, maxlen=19)
X_test_title = pad_sequences(X_test_title, maxlen=19)

# %%
class_weights = class_weight.compute_class_weight(class_weight='balanced',
                                                 classes=np.array([0, 1]),
                                                 y=y_train.values)
class_weights
# Out:
# array([0.80868545, 1.30988593])

# %%
class_weight_dict = dict(enumerate(class_weights))
class_weight_dict
# Out:
# {0: np.float64(0.8086854460093896), 1: np.float64(1.3098859315589353)}

# %%
print(X_train_title.shape)
print(X_test_title.shape)
# Out:
# (6890, 19)
# (1723, 19)

# %%
tf.random.set_seed(99)

lstm_input = Input(shape=(19,))
lstm = Embedding(input_dim=vocab_size+1,
                 output_dim=32, input_length=19)(lstm_input)
lstm = LSTM(3)(lstm)
lstm = Dropout(rate=0.5)(lstm)
lstm = Dense(3, activation='sigmoid')(lstm)
lstm_model = Model(inputs=lstm_input, outputs=lstm)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
dense_input = Input(shape=(10,))
dense = Dropout(rate=0.5)(dense_input)
dense = Dense(3, activation='sigmoid')(dense)
dense_model = Model(inputs=dense_input, outputs=dense)

# %%
print(X_train_punch.shape)
print(X_test_punch.shape)
# Out:
# (6890, 10)
# (1723, 10)

# %%
concat = concatenate([lstm_model.output, dense_model.output])
concat = Dense(6, activation= 'sigmoid' )(concat)
concat = Dense(1, activation= 'sigmoid' )(concat)
model = Model(inputs=[lstm_model.input, dense_model.input],
             outputs=concat)

# %%
plot_model(model)

# %%
model.compile(loss='binary_crossentropy',
               optimizer='adam',
               metrics=['acc'])

# %%
history = model.fit([X_train_title, X_train_punch], y_train,
                    epochs=4, batch_size=64,
                    class_weight=class_weight_dict,
                    validation_data=([X_test_title, X_test_punch],
                                     y_test))
# Out:
# Epoch 1/4
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - acc: 0.4768 - loss: 0.6927 - val_acc: 0.5461 - val_loss: 0.6896
# Epoch 2/4
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - acc: 0.7170 - loss: 0.6799 - val_acc: 0.8630 - val_loss: 0.6634
# Epoch 3/4
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - acc: 0.8374 - loss: 0.6405 - val_acc: 0.8839 - val_loss: 0.6056
# Epoch 4/4
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - acc: 0.8826 - loss: 0.5683 - val_acc: 0.8828 - val_loss: 0.5305

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.legend(['acc', 'val_acc'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss', 'val_loss'])
